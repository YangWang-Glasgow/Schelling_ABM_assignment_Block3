# %% [markdown]
# # Assignment
#
# In this assignment, you are expected to (1) explore the Schelling Agent Based Model (ABM), (2) showcase your understanding of how the Schelling model relates to key ABM properties/aspects/concepts and (3) reflect on the Schelling ABM outcomes.
#
# This document is structured as follows:
# 1. [Schelling model description](#1)
# 2. [Explore Schelling model](#2) (through hands-on runs)
# 3. [Assignment questions](#3)
# 4. [Student input](#4) (answers to the assignment question as a student input)
#
# ---

# %% [markdown]
# ## Schelling model desciption <a id='1'></a>
#
# The Schelling model is an abstract model that explores the effect of individual relocation behaviours on macroscale segregation.
# The Schelling Agent Based Moodel (ABM) includes: a space, and agents and objects that temporally interact with each other and with the model space.
# We describe each component of the Schelling ABM hereafter.
#
# ### Space
# The space is represented as a grid of square cells. Each grid cell represents a spatial unit that one agent can occupy.
# Each spatial unit has 8 immediate surrounding neighbours defined as the "Moore neighbourhood".
#
# ### Agents
# The model includes one type of agent representing an individual or a household.
# Each agent has the following state parameters (i.e., variables that dictate the state of the agent during the simulation):
# 1. `happy?`           ; indicates whether the agent is happy or not (happy agents have a percentage of surrounding similar agents above the `similarity_threshold`)
# 2. `similar-nearby`   ; the number of neighboring spatial units that have an agent similar to the agent under analysis
# 3. `other-nearby`     ; the number of neighbouring agents that are different from the agent under analysis
# 4. `total-nearby`     ; the total numebr of neighbouring agents
#
# Agents aim to settle in a spatial unit that makes them happy by being surrounding with a high ratio of simiar agents in their Moore neighbourhood. If the agent is unhappy (due to being surrounded by a high ratio of agents different from itself), the agent moves from the current spatial unit to another one randomly. The decision tree of the agents can be summarised as follows:
# - if `similar-nearby / total-nearby > similarity_threshold` (i.e., surrrounded by many similar agents) --> happy --> remain in current spatial unit
# - if `other-nearby / total-nearby > similarity_threshold` (i.e., surrrounded by many different agents) --> unhappy --> move to another random spatial unit
#
# ### Temporality
# Each time step in the model represents an iteration where each agent checks whether they are happy or not. Following the previously stated decision tree, each agent decides whether it will move or not.
#
# ---

# %% [markdown]
# ## Explore the Schelling model <a id='2'></a>
#
# To explore the Schelling model, we provide an ABM version that runs in a Python notebook.
# The models runs by calling the `run_schelling_model()` function, which has the following input parameters:
# 1. `steps`: the number of time steps the model runs
# 2. `width`: the total width of the simulated grid space where each unit is a square cell
# 3. `height`: the total height of the simulated grid space where each unit is a square cell
# 4. `density`: the ratio between the occupied and vacant spatial grid cells
#
# It should be noted that:
# 1. The type of the agent is represented visually by colours
# (<span style="background-color: yellow">yellow</span> and <span style="background-color: blue">blue</span>)
# 2. The ratio between the two different types of agents is always 0.5 (50% of the agents are yellow and the rest are blue)
# 3. At inialisation, the exact locations of agents are randomised while maintaining the required input `density`. This implies that different spatial patterns may be observed across different runs using the same input parameters.
#
# For guidance on the required Python libraries to run the model in this Python Jupyter notebook, visit the this GitHub link: [GitHub link](https://github.com/YahyaGamal/Schelling_ABM_assignment).
# If you cannot run the model in the Jupyter notebook, you can run an online version of the model through this [NetLogo Web link](https://www.netlogoweb.org/launch#https://www.netlogoweb.org/assets/modelslib/Sample%20Models/Social%20Science/Segregation.nlogox) (note that the `similarity_threshold` is labelled as `%-similar-wanted` in the NetLogo version).
#
# When exploring the model, consider modifying the input parameters while monitoring the following outputs:
# 1. The spatial patterns at the end of the runs
# 2. The percentage of unhappy agents at initialisation and at the end of the run
# 3. The rate of change of the percentage of unhappy agents in the system
#
# This exploration process will be helpful in addressing the assignment questions stated at the end of this notebook
#
# [OPTIONAL] You can explore the full python ABM code is available in the `\schelling.py` file for a deeper understanding of how the model functions. This is not required for the assignment.

# %%
! pip install numpy==1.26.4 matplotlib==3.10.0 ipython==8.32.0

# %%
## Import the function from the schelling.py file
from schelling_py12 import run_schelling_model
from IPython.display import HTML

## Run the model and visualise the outcomes
run_schelling_model(
    steps=30,
    density=0.7,
    similarity_threshold=0.7
)

HTML(filename="schelling.html")
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[2], line 6
#       3 from IPython.display import HTML
#       5 ## Run the model and visualise the outcomes
# ----> 6 run_schelling_model(
#       7     steps=30,
#       8     density=0.7,
#       9     similarity_threshold=0.7
#      10 )
#      12 HTML(filename="schelling.html")
#
# File c:\Users\yhmg1v\OneDrive - University of Glasgow\Google Drive\06 Teaching Backup\2026 Fall\ABM Module\Exercises\Assignment\Python_12\schelling_py12.py:219, in run_schelling_model(steps, width, height, density, similarity_threshold)
#     217 ax_plot.set_ylabel("Percentage")
#     218 ax_plot.set_title("Segregation Statistics")
# --> 219 ax_plot.legend(loc="upper right")
#     221 def update(frame):
#     222     model.step()
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\axes\_axes.py:323, in Axes.legend(self, *args, **kwargs)
#     206 """
#     207 Place a legend on the Axes.
#     208
#    (...)
#     320 .. plot:: gallery/text_labels_and_annotations/legend.py
#     321 """
#     322 handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
# --> 323 self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324 self.legend_._remove_method = self._remove_legend
#     325 return self.legend_
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\legend.py:563, in Legend.__init__(self, parent, handles, labels, loc, numpoints, markerscale, markerfirst, reverse, scatterpoints, scatteryoffsets, prop, fontsize, labelcolor, borderpad, labelspacing, handlelength, handleheight, handletextpad, borderaxespad, columnspacing, ncols, mode, fancybox, shadow, title, title_fontsize, framealpha, edgecolor, facecolor, bbox_to_anchor, bbox_transform, frameon, handler_map, title_fontproperties, alignment, ncol, draggable)
#     560 self._alignment = alignment
#     562 # init with null renderer
# --> 563 self._init_legend_box(handles, labels, markerfirst)
#     565 # Set legend location
#     566 self.set_loc(loc)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\legend.py:913, in Legend._init_legend_box(self, handles, labels, markerfirst)
#     910         text_list.append(textbox._text)
#     911         # Create the artist for the legend which represents the
#     912         # original artist/handle.
# --> 913         handle_list.append(handler.legend_artist(self, orig_handle,
#     914                                                  fontsize, handlebox))
#     915         handles_and_labels.append((handlebox, textbox))
#     917 columnbox = []
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\legend_handler.py:129, in HandlerBase.legend_artist(self, legend, orig_handle, fontsize, handlebox)
#     105 """
#     106 Return the artist that this HandlerBase generates for the given
#     107 original artist/handle.
#    (...)
#     122
#     123 """
#     124 xdescent, ydescent, width, height = self.adjust_drawing_area(
#     125          legend, orig_handle,
#     126          handlebox.xdescent, handlebox.ydescent,
#     127          handlebox.width, handlebox.height,
#     128          fontsize)
# --> 129 artists = self.create_artists(legend, orig_handle,
#     130                               xdescent, ydescent, width, height,
#     131                               fontsize, handlebox.get_transform())
#     133 # create_artists will return a list of artists.
#     134 for a in artists:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\legend_handler.py:303, in HandlerLine2D.create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans)
#     300 ydata = np.full_like(xdata, (height - ydescent) / 2)
#     301 legline = Line2D(xdata, ydata, markevery=markevery)
# --> 303 self.update_prop(legline, orig_handle, legend)
#     305 if legend.markerscale != 1:
#     306     newsz = legline.get_markersize() * legend.markerscale
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\legend_handler.py:88, in HandlerBase.update_prop(self, legend_handle, orig_handle, legend)
#      86 def update_prop(self, legend_handle, orig_handle, legend):
# ---> 88     self._update_prop(legend_handle, orig_handle)
#      90     legend._set_artist_props(legend_handle)
#      91     legend_handle.set_clip_box(None)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\legend_handler.py:79, in HandlerBase._update_prop(self, legend_handle, orig_handle)
#      77 def _update_prop(self, legend_handle, orig_handle):
#      78     if self._update_prop_func is None:
# ---> 79         self._default_update_prop(legend_handle, orig_handle)
#      80     else:
#      81         self._update_prop_func(legend_handle, orig_handle)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\legend_handler.py:84, in HandlerBase._default_update_prop(self, legend_handle, orig_handle)
#      83 def _default_update_prop(self, legend_handle, orig_handle):
# ---> 84     legend_handle.update_from(orig_handle)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\lines.py:1356, in Line2D.update_from(self, other)
#    1353 self._solidjoinstyle = other._solidjoinstyle
#    1355 self._linestyle = other._linestyle
# -> 1356 self._marker = MarkerStyle(marker=other._marker)
#    1357 self._drawstyle = other._drawstyle
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\markers.py:255, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     253 self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     254 self._set_fillstyle(fillstyle)
# --> 255 self._set_marker(marker)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\markers.py:332, in MarkerStyle._set_marker(self, marker)
#     330     self._marker_function = self._set_tuple_marker
#     331 elif isinstance(marker, MarkerStyle):
# --> 332     self.__dict__ = copy.deepcopy(marker.__dict__)
#     333 else:
#     334     try:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:131, in deepcopy(x, memo, _nil)
#     129 copier = _deepcopy_dispatch.get(cls)
#     130 if copier is not None:
# --> 131     y = copier(x, memo)
#     132 else:
#     133     if issubclass(cls, type):
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:202, in _deepcopy_dict(x, memo, deepcopy)
#     200 memo[id(x)] = y
#     201 for key, value in x.items():
# --> 202     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     203 return y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:138, in deepcopy(x, memo, _nil)
#     136 copier = getattr(x, "__deepcopy__", None)
#     137 if copier is not None:
# --> 138     y = copier(memo)
#     139 else:
#     140     reductor = dispatch_table.get(cls)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\path.py:285, in Path.__deepcopy__(self, memo)
#     280 """
#     281 Return a deepcopy of the `Path`.  The `Path` will not be
#     282 readonly, even if the source `Path` is.
#     283 """
#     284 # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 285 p = copy.deepcopy(super(), memo)
#     286 p._readonly = False
#     287 return p
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:157, in deepcopy(x, memo, _nil)
#     155                 y = x
#     156             else:
# --> 157                 y = _reconstruct(x, memo, *rv)
#     159 # If is its own copy, don't memoize.
#     160 if y is not x:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:234, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     232 if deep and args:
#     233     args = (deepcopy(arg, memo) for arg in args)
# --> 234 y = func(*args)
#     235 if deep:
#     236     memo[id(x)] = y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:233, in <genexpr>(.0)
#     231 deep = memo is not None
#     232 if deep and args:
# --> 233     args = (deepcopy(arg, memo) for arg in args)
#     234 y = func(*args)
#     235 if deep:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:138, in deepcopy(x, memo, _nil)
#     136 copier = getattr(x, "__deepcopy__", None)
#     137 if copier is not None:
# --> 138     y = copier(memo)
#     139 else:
#     140     reductor = dispatch_table.get(cls)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\path.py:285, in Path.__deepcopy__(self, memo)
#     280 """
#     281 Return a deepcopy of the `Path`.  The `Path` will not be
#     282 readonly, even if the source `Path` is.
#     283 """
#     284 # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 285 p = copy.deepcopy(super(), memo)
#     286 p._readonly = False
#     287 return p
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:157, in deepcopy(x, memo, _nil)
#     155                 y = x
#     156             else:
# --> 157                 y = _reconstruct(x, memo, *rv)
#     159 # If is its own copy, don't memoize.
#     160 if y is not x:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:234, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     232 if deep and args:
#     233     args = (deepcopy(arg, memo) for arg in args)
# --> 234 y = func(*args)
#     235 if deep:
#     236     memo[id(x)] = y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:233, in <genexpr>(.0)
#     231 deep = memo is not None
#     232 if deep and args:
# --> 233     args = (deepcopy(arg, memo) for arg in args)
#     234 y = func(*args)
#     235 if deep:
#
#     [... skipping similar frames: Path.__deepcopy__ at line 285 (590 times), deepcopy at line 138 (590 times), deepcopy at line 157 (590 times), <genexpr> at line 233 (589 times), _reconstruct at line 234 (589 times)]
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:234, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     232 if deep and args:
#     233     args = (deepcopy(arg, memo) for arg in args)
# --> 234 y = func(*args)
#     235 if deep:
#     236     memo[id(x)] = y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:233, in <genexpr>(.0)
#     231 deep = memo is not None
#     232 if deep and args:
# --> 233     args = (deepcopy(arg, memo) for arg in args)
#     234 y = func(*args)
#     235 if deep:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:138, in deepcopy(x, memo, _nil)
#     136 copier = getattr(x, "__deepcopy__", None)
#     137 if copier is not None:
# --> 138     y = copier(memo)
#     139 else:
#     140     reductor = dispatch_table.get(cls)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\path.py:285, in Path.__deepcopy__(self, memo)
#     280 """
#     281 Return a deepcopy of the `Path`.  The `Path` will not be
#     282 readonly, even if the source `Path` is.
#     283 """
#     284 # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 285 p = copy.deepcopy(super(), memo)
#     286 p._readonly = False
#     287 return p
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:157, in deepcopy(x, memo, _nil)
#     155                 y = x
#     156             else:
# --> 157                 y = _reconstruct(x, memo, *rv)
#     159 # If is its own copy, don't memoize.
#     160 if y is not x:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:233, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     231 deep = memo is not None
#     232 if deep and args:
# --> 233     args = (deepcopy(arg, memo) for arg in args)
#     234 y = func(*args)
#     235 if deep:
#
# RecursionError: maximum recursion depth exceeded
# Error in callback <function _draw_all_if_interactive at 0x000002816581A4B0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\backends\backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\axis.py:1387, in Axis.draw(self, renderer, *args, **kwargs)
#    1384     return
#    1385 renderer.open_group(__name__, gid=self.get_gid())
# -> 1387 ticks_to_draw = self._update_ticks()
#    1388 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1390 for tick in ticks_to_draw:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\axis.py:1277, in Axis._update_ticks(self)
#    1275 major_locs = self.get_majorticklocs()
#    1276 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1277 major_ticks = self.get_major_ticks(len(major_locs))
#    1278 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#    1279     tick.update_position(loc)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\axis.py:1628, in Axis.get_major_ticks(self, numticks)
#    1626     tick = self._get_tick(major=True)
#    1627     self.majorTicks.append(tick)
# -> 1628     self._copy_tick_props(self.majorTicks[0], tick)
#    1630 return self.majorTicks[:numticks]
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\axis.py:1582, in Axis._copy_tick_props(self, src, dest)
#    1580 dest.label1.update_from(src.label1)
#    1581 dest.label2.update_from(src.label2)
# -> 1582 dest.tick1line.update_from(src.tick1line)
#    1583 dest.tick2line.update_from(src.tick2line)
#    1584 dest.gridline.update_from(src.gridline)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\lines.py:1356, in Line2D.update_from(self, other)
#    1353 self._solidjoinstyle = other._solidjoinstyle
#    1355 self._linestyle = other._linestyle
# -> 1356 self._marker = MarkerStyle(marker=other._marker)
#    1357 self._drawstyle = other._drawstyle
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\markers.py:255, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     253 self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     254 self._set_fillstyle(fillstyle)
# --> 255 self._set_marker(marker)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\markers.py:332, in MarkerStyle._set_marker(self, marker)
#     330     self._marker_function = self._set_tuple_marker
#     331 elif isinstance(marker, MarkerStyle):
# --> 332     self.__dict__ = copy.deepcopy(marker.__dict__)
#     333 else:
#     334     try:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:131, in deepcopy(x, memo, _nil)
#     129 copier = _deepcopy_dispatch.get(cls)
#     130 if copier is not None:
# --> 131     y = copier(x, memo)
#     132 else:
#     133     if issubclass(cls, type):
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:202, in _deepcopy_dict(x, memo, deepcopy)
#     200 memo[id(x)] = y
#     201 for key, value in x.items():
# --> 202     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     203 return y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:138, in deepcopy(x, memo, _nil)
#     136 copier = getattr(x, "__deepcopy__", None)
#     137 if copier is not None:
# --> 138     y = copier(memo)
#     139 else:
#     140     reductor = dispatch_table.get(cls)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\path.py:285, in Path.__deepcopy__(self, memo)
#     280 """
#     281 Return a deepcopy of the `Path`.  The `Path` will not be
#     282 readonly, even if the source `Path` is.
#     283 """
#     284 # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 285 p = copy.deepcopy(super(), memo)
#     286 p._readonly = False
#     287 return p
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:157, in deepcopy(x, memo, _nil)
#     155                 y = x
#     156             else:
# --> 157                 y = _reconstruct(x, memo, *rv)
#     159 # If is its own copy, don't memoize.
#     160 if y is not x:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:234, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     232 if deep and args:
#     233     args = (deepcopy(arg, memo) for arg in args)
# --> 234 y = func(*args)
#     235 if deep:
#     236     memo[id(x)] = y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:233, in <genexpr>(.0)
#     231 deep = memo is not None
#     232 if deep and args:
# --> 233     args = (deepcopy(arg, memo) for arg in args)
#     234 y = func(*args)
#     235 if deep:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:138, in deepcopy(x, memo, _nil)
#     136 copier = getattr(x, "__deepcopy__", None)
#     137 if copier is not None:
# --> 138     y = copier(memo)
#     139 else:
#     140     reductor = dispatch_table.get(cls)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\path.py:285, in Path.__deepcopy__(self, memo)
#     280 """
#     281 Return a deepcopy of the `Path`.  The `Path` will not be
#     282 readonly, even if the source `Path` is.
#     283 """
#     284 # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 285 p = copy.deepcopy(super(), memo)
#     286 p._readonly = False
#     287 return p
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:157, in deepcopy(x, memo, _nil)
#     155                 y = x
#     156             else:
# --> 157                 y = _reconstruct(x, memo, *rv)
#     159 # If is its own copy, don't memoize.
#     160 if y is not x:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:234, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     232 if deep and args:
#     233     args = (deepcopy(arg, memo) for arg in args)
# --> 234 y = func(*args)
#     235 if deep:
#     236     memo[id(x)] = y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:233, in <genexpr>(.0)
#     231 deep = memo is not None
#     232 if deep and args:
# --> 233     args = (deepcopy(arg, memo) for arg in args)
#     234 y = func(*args)
#     235 if deep:
#
#     [... skipping similar frames: Path.__deepcopy__ at line 285 (590 times), deepcopy at line 138 (590 times), <genexpr> at line 233 (589 times), _reconstruct at line 234 (589 times), deepcopy at line 157 (589 times)]
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:157, in deepcopy(x, memo, _nil)
#     155                 y = x
#     156             else:
# --> 157                 y = _reconstruct(x, memo, *rv)
#     159 # If is its own copy, don't memoize.
#     160 if y is not x:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:234, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     232 if deep and args:
#     233     args = (deepcopy(arg, memo) for arg in args)
# --> 234 y = func(*args)
#     235 if deep:
#     236     memo[id(x)] = y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:233, in <genexpr>(.0)
#     231 deep = memo is not None
#     232 if deep and args:
# --> 233     args = (deepcopy(arg, memo) for arg in args)
#     234 y = func(*args)
#     235 if deep:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:138, in deepcopy(x, memo, _nil)
#     136 copier = getattr(x, "__deepcopy__", None)
#     137 if copier is not None:
# --> 138     y = copier(memo)
#     139 else:
#     140     reductor = dispatch_table.get(cls)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\path.py:285, in Path.__deepcopy__(self, memo)
#     280 """
#     281 Return a deepcopy of the `Path`.  The `Path` will not be
#     282 readonly, even if the source `Path` is.
#     283 """
#     284 # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 285 p = copy.deepcopy(super(), memo)
#     286 p._readonly = False
#     287 return p
#
# RecursionError: maximum recursion depth exceeded
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\backend_bases.py:2158, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2155     # we do this instead of `self.figure.draw_without_rendering`
#    2156     # so that we can inject the orientation
#    2157     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2158         self.figure.draw(renderer)
#    2159 if bbox_inches:
#    2160     if bbox_inches == "tight":
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\axis.py:1387, in Axis.draw(self, renderer, *args, **kwargs)
#    1384     return
#    1385 renderer.open_group(__name__, gid=self.get_gid())
# -> 1387 ticks_to_draw = self._update_ticks()
#    1388 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1390 for tick in ticks_to_draw:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\axis.py:1277, in Axis._update_ticks(self)
#    1275 major_locs = self.get_majorticklocs()
#    1276 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1277 major_ticks = self.get_major_ticks(len(major_locs))
#    1278 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#    1279     tick.update_position(loc)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\axis.py:1628, in Axis.get_major_ticks(self, numticks)
#    1626     tick = self._get_tick(major=True)
#    1627     self.majorTicks.append(tick)
# -> 1628     self._copy_tick_props(self.majorTicks[0], tick)
#    1630 return self.majorTicks[:numticks]
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\axis.py:1582, in Axis._copy_tick_props(self, src, dest)
#    1580 dest.label1.update_from(src.label1)
#    1581 dest.label2.update_from(src.label2)
# -> 1582 dest.tick1line.update_from(src.tick1line)
#    1583 dest.tick2line.update_from(src.tick2line)
#    1584 dest.gridline.update_from(src.gridline)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\lines.py:1356, in Line2D.update_from(self, other)
#    1353 self._solidjoinstyle = other._solidjoinstyle
#    1355 self._linestyle = other._linestyle
# -> 1356 self._marker = MarkerStyle(marker=other._marker)
#    1357 self._drawstyle = other._drawstyle
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\markers.py:255, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     253 self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     254 self._set_fillstyle(fillstyle)
# --> 255 self._set_marker(marker)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\markers.py:332, in MarkerStyle._set_marker(self, marker)
#     330     self._marker_function = self._set_tuple_marker
#     331 elif isinstance(marker, MarkerStyle):
# --> 332     self.__dict__ = copy.deepcopy(marker.__dict__)
#     333 else:
#     334     try:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:131, in deepcopy(x, memo, _nil)
#     129 copier = _deepcopy_dispatch.get(cls)
#     130 if copier is not None:
# --> 131     y = copier(x, memo)
#     132 else:
#     133     if issubclass(cls, type):
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:202, in _deepcopy_dict(x, memo, deepcopy)
#     200 memo[id(x)] = y
#     201 for key, value in x.items():
# --> 202     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     203 return y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:138, in deepcopy(x, memo, _nil)
#     136 copier = getattr(x, "__deepcopy__", None)
#     137 if copier is not None:
# --> 138     y = copier(memo)
#     139 else:
#     140     reductor = dispatch_table.get(cls)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\path.py:285, in Path.__deepcopy__(self, memo)
#     280 """
#     281 Return a deepcopy of the `Path`.  The `Path` will not be
#     282 readonly, even if the source `Path` is.
#     283 """
#     284 # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 285 p = copy.deepcopy(super(), memo)
#     286 p._readonly = False
#     287 return p
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:157, in deepcopy(x, memo, _nil)
#     155                 y = x
#     156             else:
# --> 157                 y = _reconstruct(x, memo, *rv)
#     159 # If is its own copy, don't memoize.
#     160 if y is not x:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:234, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     232 if deep and args:
#     233     args = (deepcopy(arg, memo) for arg in args)
# --> 234 y = func(*args)
#     235 if deep:
#     236     memo[id(x)] = y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:233, in <genexpr>(.0)
#     231 deep = memo is not None
#     232 if deep and args:
# --> 233     args = (deepcopy(arg, memo) for arg in args)
#     234 y = func(*args)
#     235 if deep:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:138, in deepcopy(x, memo, _nil)
#     136 copier = getattr(x, "__deepcopy__", None)
#     137 if copier is not None:
# --> 138     y = copier(memo)
#     139 else:
#     140     reductor = dispatch_table.get(cls)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\path.py:285, in Path.__deepcopy__(self, memo)
#     280 """
#     281 Return a deepcopy of the `Path`.  The `Path` will not be
#     282 readonly, even if the source `Path` is.
#     283 """
#     284 # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 285 p = copy.deepcopy(super(), memo)
#     286 p._readonly = False
#     287 return p
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:157, in deepcopy(x, memo, _nil)
#     155                 y = x
#     156             else:
# --> 157                 y = _reconstruct(x, memo, *rv)
#     159 # If is its own copy, don't memoize.
#     160 if y is not x:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:234, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     232 if deep and args:
#     233     args = (deepcopy(arg, memo) for arg in args)
# --> 234 y = func(*args)
#     235 if deep:
#     236     memo[id(x)] = y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:233, in <genexpr>(.0)
#     231 deep = memo is not None
#     232 if deep and args:
# --> 233     args = (deepcopy(arg, memo) for arg in args)
#     234 y = func(*args)
#     235 if deep:
#
#     [... skipping similar frames: Path.__deepcopy__ at line 285 (589 times), deepcopy at line 138 (589 times), <genexpr> at line 233 (588 times), _reconstruct at line 234 (588 times), deepcopy at line 157 (588 times)]
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:157, in deepcopy(x, memo, _nil)
#     155                 y = x
#     156             else:
# --> 157                 y = _reconstruct(x, memo, *rv)
#     159 # If is its own copy, don't memoize.
#     160 if y is not x:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:234, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     232 if deep and args:
#     233     args = (deepcopy(arg, memo) for arg in args)
# --> 234 y = func(*args)
#     235 if deep:
#     236     memo[id(x)] = y
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:233, in <genexpr>(.0)
#     231 deep = memo is not None
#     232 if deep and args:
# --> 233     args = (deepcopy(arg, memo) for arg in args)
#     234 y = func(*args)
#     235 if deep:
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\copy.py:138, in deepcopy(x, memo, _nil)
#     136 copier = getattr(x, "__deepcopy__", None)
#     137 if copier is not None:
# --> 138     y = copier(memo)
#     139 else:
#     140     reductor = dispatch_table.get(cls)
#
# File c:\Users\yhmg1v\AppData\Local\anaconda3\envs\urban5160\Lib\site-packages\matplotlib\path.py:285, in Path.__deepcopy__(self, memo)
#     280 """
#     281 Return a deepcopy of the `Path`.  The `Path` will not be
#     282 readonly, even if the source `Path` is.
#     283 """
#     284 # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
# --> 285 p = copy.deepcopy(super(), memo)
#     286 p._readonly = False
#     287 return p
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ---
# ## Assignment questions <a id='3'></a>
#
# Part 1: What are ABMs, and what are their key features? Cite at least 2 examples.
#
# ---
#
# Part 2:
#
# Questions that may not need support from run results:
# 1. What are the key aims of the Schelling ABM?
#     - For instance, does it aim to predict, understand reality, explore different scenarios?
#     - Elaborate on how well you think the model achieves such aim(s)
# 2. What are the key ABM properties that the Schelling ABM showcases?
#     - Consider concepts such as emergence, complexity, interactions, behaviours... etc.
# 3. How can the insights from this ABM be useful in real life applications?
#     - For instance, can it be used to inform policies, or to enhance our understanding of segregation?
#
# Questions that can be supported by runs results:
#
# 4. How does the (spatial) outcomes change across runs with similar model inputs?
#     - In other words, does the random spatial initialisation of agents affect the macroscale outcomes?
# 5. How does modifying the `similarity_threshold` affect the outcomes? you can consider the following at different `similarity_threshold` values:
#     - whether segregation is reached
#     - the rate of reaching a stable spatial output if applicable (i.e., the number of steps)
# 6. To what extent does the initial state affects the outcomes of the model?
#     - Consider modifying the `density` to explore the outcomes?
#
# ---
#
# Part 3: Critically Evaluate the Schelling model (is it fit for purpose?)
#
# ---
#
# We estimate 1500 word assignments. Students are expected to add their writing to this Jupyter notebook and submit as an HTML.
